# %%
# -*- coding: utf-8 -*-
import pyodbc
import pandas as pd
import numpy as np
import os.path
#from datetime import time
# %matplotlib inline

# %%
um = pd.read_excel('UM_2.xlsx', sheetname='Sessions', header=0,)
speak = pd.read_excel('UM_2.xlsx', sheetname='Speakers', header=0 )
#print um.dtypes
speak = speak.apply(lambda x: x.str.strip() if x.dtype == "object" else x)
speak['bio'] = speak.SpeakerBio.str.replace('.pdf', '.html')
um = um.fillna('')
speak = speak.fillna('')
um['speakers'] = um[um.columns[7:13]].applymap(lambda x: [x] if (x != '') else []).sum(1).tolist()
#um = um.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
# read in biographies from html.
bx = []
for sp in speak.bio:
    if os.path.isfile(sp):
        f = open(str(sp),'r')
        message = f.read()
        #print(message)
        f.close()
        bx.append(message)
    else:
        bx.append('')
speak['biotext'] = bx  

# Concatenate speaker full name to "speaker" column for matching purposes.
cat = []
for row in speak.itertuples():
    if row.SpeakerMiddle:
        cat.append(row.SpeakerFirstName + ' ' + row.SpeakerMiddle + ' ' + row.SpeakerLastName)
    else:
        cat.append(row.SpeakerFirstName  + ' ' + row.SpeakerLastName)
        
speak['speaker'] = cat

# %%
um[um.Speaker6 != ''].speakers
# Out:
# 57    [Steven K. Mignogna, Jo Ann Engelhardt, Terren...
# Name: speakers, dtype: object

# %%
um.to_json('umtest.json',orient='records',date_format='iso' )

# %%
speak.to_json('speakers.json',orient='records' )

# %%
speak[['biotext', 'bio','speaker']][19:50]
# Out:
#                                               biotext  \
# 19  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 20  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 21  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 22  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 23  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 24  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 25  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 26  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 27  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 28  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 29  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 30  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 31  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 32  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 33  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 34  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 35  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 36  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 37  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 38  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 39  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 40  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 41  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 42  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 43  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 44  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 45  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 46  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 47  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 48  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
# 49  <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//...
#
#                           bio                    speaker
# 19     Flubacher_Bio2018.html          Todd A. Flubacher
# 20           Fox_Bio2018.html  Charles D. "Skip" Fox, IV
# 21      Franklin_Bio2018.html       Terrence M. Franklin
# 22        Frolik_Bio2018.html            Lawrence Frolik
# 23        Gordon_Bio2018.html          Michael M. Gordon
# 24          Hall_Bio2018.html                Martin Hall
# 25      Halperin_Bio2018.html           Alan S. Halperin
# 26    Harrington_Bio2018.html        Carol A. Harrington
# 27      Harrison_Bio2018.html          Ellen K. Harrison
# 28        Heller_Bio2018.html              Amy E. Heller
# 29     Henderson_Bio2018.html         Nancy G. Henderson
# 30     Hennessey_Bio2018.html       William T. Hennessey
# 31       Johnson_Bio2018.html        Sarah Moore Johnson
# 32        Kanyuk_Bio2018.html              Amy K. Kanyuk
# 33        Krooks_Bio2018.html          Bernard A. Krooks
# 34           Lee_Bio2018.html                Paul S. Lee
# 35         Lewis_Bio2018.html           Kristen M. Lewis
# 36  Loomis-Price_Bio2018.html     Stephanie Loomis-Price
# 37        Magill_Bio2018.html             R. Hugh Magill
# 38       Mancini_Bio2018.html           Mary Ann Mancini
# 39        Marion_Bio2018.html            James M. Marion
# 40     McCaffrey_Bio2018.html        Carlyn S. McCaffrey
# 41      McCarten_Bio2018.html          James M. McCarten
# 42      McKinnon_Bio2018.html      Michele A.W. McKinnon
# 43        Medina_Bio2018.html               Eliam Medina
# 44      Mezzullo_Bio2018.html          Louis A. Mezzullo
# 45      Mignogna_Bio2018.html         Steven K. Mignogna
# 46         Moore_Bio2018.html              M. Read Moore
# 47         Nenno_Bio2018.html           Richard W. Nenno
# 48       Osborne_Bio2018.html          J. Lee E. Osborne
# 49       Pennell_Bio2018.html         Jeffrey N. Pennell
